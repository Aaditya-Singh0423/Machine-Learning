# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("laptops.csv",encoding= "Latin-1")      # Load the data into a DataFrame
df
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0:2]                          #first 2 rows
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
#
#                                Screen                   CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
#
#   Operating System Version  Weight Price (Euros)
# 0                      NaN  1.37kg       1339,69
# 1                      NaN  1.34kg        898,94

# %%
df.iloc[0:2,0:2]                               #first 2 rows and first 2 columns
# Out:
#   Manufacturer   Model Name
# 0        Apple  MacBook Pro
# 1        Apple  Macbook Air

# %%
df.iloc[0:2,0]                                 #first 2 rows and first column
# Out:
# 0    Apple
# 1    Apple
# Name: Manufacturer, dtype: object

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Name': ['Amit', 'Priya', 'Rahul', 'Sneha', 'Karan'],
    'Age': [23, 25, 22, 24, 26],
    'City': ['Delhi', 'Mumbai', 'Pune', 'Bangalore', 'Chennai'],
    'Score': [85, 90, 78, 88, 92]
}                                                                               # Sample data

df2 = pd.DataFrame(data, index=['s1', 's2', 's3', 's4', 's5'])

# %%
df2
# Out:
#      Name  Age       City  Score
# s1   Amit   23      Delhi     85
# s2  Priya   25     Mumbai     90
# s3  Rahul   22       Pune     78
# s4  Sneha   24  Bangalore     88
# s5  Karan   26    Chennai     92

# %%
df2.iloc[0:2,0]
# Out:
# s1     Amit
# s2    Priya
# Name: Name, dtype: object

# %%
df2.iloc[0:2,[0,2]]                    #first 2 rows and first and third columns #fancy indexing
# Out:
#      Name    City
# s1   Amit   Delhi
# s2  Priya  Mumbai

# %%
df2.loc["s1":"s3"]                      #label based indexing on basis of name
# Out:
#      Name  Age    City  Score
# s1   Amit   23   Delhi     85
# s2  Priya   25  Mumbai     90
# s3  Rahul   22    Pune     78

# %%
df2.loc["s1":"s3",["Name","City"]]          #label based indexing
# Out:
#      Name    City
# s1   Amit   Delhi
# s2  Priya  Mumbai
# s3  Rahul    Pune

# %%
df2.columns
# Out:
# Index(['Name', 'Age', 'City', 'Score'], dtype='object')

# %%
#change the city name with age 25 tp kolkata using iloc
cond=df2['Age']==25
cond
# Out:
# s1    False
# s2     True
# s3    False
# s4    False
# s5    False
# Name: Age, dtype: bool

# %%
X=df2.loc[cond]
X
# Out:
#      Name  Age    City  Score
# s2  Priya   25  Mumbai     90

# %%
X.loc[:,"Age"]=22
X
# Out:
#      Name  Age    City  Score
# s2  Priya   22  Mumbai     90

# %%
df2.loc[df2["Age"]==25,"City"]="Kolkata"               #changing value using loc
df2
# Out:
#      Name  Age       City  Score
# s1   Amit   23      Delhi     85
# s2  Priya   25    Kolkata     90
# s3  Rahul   22       Pune     78
# s4  Sneha   24  Bangalore     88
# s5  Karan   26    Chennai     92

# %%
df2.loc[(df2["Age"]>20)&(df2["Age"]<=25),"Age"]=22               #changing value using loc
df2
# Out:
#      Name  Age       City  Score
# s1   Amit   22      Delhi     85
# s2  Priya   22    Kolkata     90
# s3  Rahul   22       Pune     78
# s4  Sneha   22  Bangalore     88
# s5  Karan   26    Chennai     92

# %%
df.info()                          # Get a concise summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
# df.columns=['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
# 'CPU', 'RAM', 'storage', 'GPU', 'os',
# 'os_version', 'weight', 'price_euros']                                             # Rename columns to avoid

# %%
def clean_column(ele):
    ele=ele.strip()                           # Remove leading/trailing whitespace
    ele=ele.lower()                           # Convert to lowercase
    ele=ele.replace(" ","_")                  # Replace spaces with underscores
    ele=ele.replace("(","")                   # Remove opening parentheses
    ele=ele.replace(")","")                   # Remove closing parentheses
    ele=ele.replace("operating_system","os")  # Abbreviate 'operating_system' to 'os'
    ele=ele.replace("os_version","osv")       # Abbreviate 'Operating_System' to 'os'
    return ele

# %%
for name in df.columns:
    clean_name=clean_column(name)
    df.rename(columns={name:clean_name},inplace=True)          # Rename columns using the clean_column function

# %%
df.columns
# Out:
# Index(['manufacturer', 'model_name', 'category', 'screen_size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'os', 'osv', 'weight', 'price_euros'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   object
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  osv           1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
df["screen_size"].unique()
# Out:
# array(['13.3"', '15.6"', '15.4"', '14.0"', '12.0"', '11.6"', '17.3"',
#        '10.1"', '13.5"', '12.5"', '13.0"', '18.4"', '13.9"', '12.3"',
#        '17.0"', '15.0"', '14.1"', '11.3"'], dtype=object)

# %%
#accessor is a special method which is used to access the values of a particular datatype in pandas dataframe.
df["screen_size"]=df["screen_size"].str.replace('"',"")

# %%
df["screen_size"].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14.0', '12.0', '11.6', '17.3', '10.1',
#        '13.5', '12.5', '13.0', '18.4', '13.9', '12.3', '17.0', '15.0',
#        '14.1', '11.3'], dtype=object)

# %%
df["screen_size"]=df["screen_size"].astype("float")              # Convert screen_size to float

# %%
df["cpu"].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
df["cpu"]=df["cpu"].str.split(" ")         # Split the 'cpu' column values into lists based on spaces

# %%
df["cpu"]
# Out:
# 0                         [Intel, Core, i5, 2.3GHz]
# 1                         [Intel, Core, i5, 1.8GHz]
# 2                  [Intel, Core, i5, 7200U, 2.5GHz]
# 3                         [Intel, Core, i7, 2.7GHz]
# 4                         [Intel, Core, i5, 3.1GHz]
#                            ...
# 1298               [Intel, Core, i7, 6500U, 2.5GHz]
# 1299               [Intel, Core, i7, 6500U, 2.5GHz]
# 1300    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# 1301               [Intel, Core, i7, 6500U, 2.5GHz]
# 1302    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# Name: cpu, Length: 1303, dtype: object

# %%
count_cpu=df["cpu"].str[0].value_counts()         # Extract the first element from the 'cpu' list and get value
count_cpu                                         #normalize=True for percentage
# Out:
# cpu
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
#create a new column of 'cpu_name' with the first element of the 'cpu' list
df["cpu_name"]=df["cpu"].str[0]
df["cpu_name"].value_counts()
# Out:
# cpu_name
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                               cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600         [Intel, Core, i5, 2.3GHz]   8GB
# 1                            1440x900         [Intel, Core, i5, 1.8GHz]   8GB
# 2                   Full HD 1920x1080  [Intel, Core, i5, 7200U, 2.5GHz]   8GB
# 3  IPS Panel Retina Display 2880x1800         [Intel, Core, i7, 2.7GHz]  16GB
# 4  IPS Panel Retina Display 2560x1600         [Intel, Core, i5, 3.1GHz]   8GB
#
#                storage                           gpu     os  osv  weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  NaN  1.37kg
# ...

# %%
#unsplit the 'cpu' column back to string
df["cpu"]=df["cpu"].str.join(" ")
df["cpu"]
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1298              Intel Core i7 6500U 2.5GHz
# 1299              Intel Core i7 6500U 2.5GHz
# 1300    Intel Celeron Dual Core N3050 1.6GHz
# 1301              Intel Core i7 6500U 2.5GHz
# 1302    Intel Celeron Dual Core N3050 1.6GHz
# Name: cpu, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os  osv  weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  NaN  1.37kg
# ...

# %%
df.info()
df["ram"].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   object
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  osv           1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
#  13  cpu_name      1303 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 142.6+ KB
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
df["ram"]=df["ram"].str.replace("GB","").astype("int")        # Remove 'GB' and convert to integer
df["ram"].unique()
# Out:
# array([ 8, 16,  4,  2, 12,  6, 32, 24, 64])

# %%
df.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                         cpu  ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                storage                           gpu     os  osv  weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  NaN  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  NaN  1.34kg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   int64
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  osv           1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
#  13  cpu_name      1303 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 142.6+ KB

# %%
df["storage"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '1GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid',
#        '512GB SSD +  1TB Hybrid', '256GB SSD +  1TB Hybrid'], dtype=object)

# %%
def convert_to_gb(value):                                            #convert storage to GB
    parts = re.findall(r'(\d+\.?\d*)\s*(TB|GB)', str(value))         #find the number and unit
    total_gb = 0                                                     #initialize total_gb
    for amount, unit in parts:                                       #iterate over found parts
        amount = float(amount)                                       #convert to float
        if unit.upper() == 'TB':                                     #convert TB to GB
            amount *= 1024                                           # Convert TB → GB
        total_gb += amount                                           #sum up the total_gb
    return total_gb                                                  # Return total storage in GB

# %%
df['storage_gb'] = df['storage'].apply(convert_to_gb).astype(int)    # Apply the conversion function and convert to integer

# %%
df
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       screen_size                                      screen  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  1303 non-null   object
#  1   model_name    1303 non-null   object
#  2   category      1303 non-null   object
#  3   screen_size   1303 non-null   float64
#  4   screen        1303 non-null   object
#  5   cpu           1303 non-null   object
#  6   ram           1303 non-null   int64
#  7   storage       1303 non-null   object
#  8   gpu           1303 non-null   object
#  9   os            1303 non-null   object
#  10  osv           1133 non-null   object
#  11  weight        1303 non-null   object
#  12  price_euros   1303 non-null   object
#  13  cpu_name      1303 non-null   object
#  14  storage_gb    1303 non-null   int64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 152.8+ KB

# %%
# test_na=pd.Series([2,3,4,np.nan,np.nan])                     # Create a Series with missing values

# %%
# test_na.isna()                                               # Check for missing values

# %%
# test_na.isna().sum()                                         # Count the number of missing values

# %%
# test_na.isnull()                                             # Check for missing values using isnull()

# %% [markdown]
# # Missing Values Devisions-
# * Missing at Random
# * Missing not at random
# * Missing completely at random

# %%
df.isna().sum()                           # Check for missing values in the DataFrame
# Out:
# manufacturer      0
# model_name        0
# category          0
# screen_size       0
# screen            0
# cpu               0
# ram               0
# storage           0
# gpu               0
# os                0
# osv             170
# weight            0
# price_euros       0
# cpu_name          0
# storage_gb        0
# dtype: int64

# %%
#find the values of os where osv have null values using loc and iloc
df.loc[df['osv'].isna(),'os']
# Out:
# 0       macOS
# 1       macOS
# 2       No OS
# 3       macOS
# 4       macOS
#         ...
# 1267    Linux
# 1277    Linux
# 1281    Linux
# 1291    Linux
# 1295    Linux
# Name: os, Length: 170, dtype: object

# %%
#Mask the missing values in the osv column with the corresponding values in the os column
Oper=df['osv'].fillna(df['os'])
Oper
# Out:
# 0       macOS
# 1       macOS
# 2       No OS
# 3       macOS
# 4       macOS
#         ...
# 1298       10
# 1299       10
# 1300       10
# 1301       10
# 1302       10
# Name: osv, Length: 1303, dtype: object

# %%
df.loc[df['osv'].isna(),'os'].value_counts()
# Out:
# os
# No OS        66
# Linux        62
# Chrome OS    27
# macOS        13
# Android       2
# Name: count, dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          13
# Mac OS          8
# Android         2
# Name: count, dtype: int64

# %%
df['osv'].value_counts()
# Out:
# osv
# 10      1072
# 7         45
# X          8
# 10 S       8
# Name: count, dtype: int64

# %%
df.loc[df['os']=='macOS','osv']="X"
df.loc[df['os']=='Linux','osv']="Y"

# %%
df.loc[df['osv'].isna(),'os'].value_counts()
# Out:
# os
# No OS        66
# Chrome OS    27
# Android       2
# Name: count, dtype: int64

# %%
df["weight"]=df["weight"].str.replace("kg","").str.replace("s","").astype(float)      # Remove 'kg' and convert to float
df["weight"].unique()
# Out:
# array([1.37 , 1.34 , 1.86 , 1.83 , 2.1  , 2.04 , 1.3  , 1.6  , 2.2  ,
#        0.92 , 1.22 , 0.98 , 2.5  , 1.62 , 1.91 , 2.3  , 1.35 , 1.88 ,
#        1.89 , 1.65 , 2.71 , 1.2  , 1.44 , 2.8  , 2.   , 2.65 , 2.77 ,
#        3.2  , 0.69 , 1.49 , 2.4  , 2.13 , 2.43 , 1.7  , 1.4  , 1.8  ,
#        1.9  , 3.   , 1.252, 2.7  , 2.02 , 1.63 , 1.96 , 1.21 , 2.45 ,
#        1.25 , 1.5  , 2.62 , 1.38 , 1.58 , 1.85 , 1.23 , 1.26 , 2.16 ,
#        2.36 , 2.05 , 1.32 , 1.75 , 0.97 , 2.9  , 2.56 , 1.48 , 1.74 ,
#        1.1  , 1.56 , 2.03 , 1.05 , 4.4  , 1.29 , 1.95 , 2.06 , 1.12 ,
#        1.42 , 3.49 , 3.35 , 2.23 , 4.42 , 2.69 , 2.37 , 4.7  , 3.6  ,
#        2.08 , 4.3  , 1.68 , 1.41 , 4.14 , 2.18 , 2.24 , 2.67 , 2.14 ,
#        1.36 , 2.25 , 2.15 , 2.19 , 2.54 , 3.42 , 1.28 , 2.33 , 1.45 ,
#        2.79 , 1.84 , 2.6  , 2.26 , 3.25 , 1.59 , 1.13 , 1.78 , 1.15 ,
#        1.27 , 1.43 , 2.31 , 1.16 , 1.64 , 2.17 , 1.47 , 3.78 , 1.79 ,
# ...

# %%
df.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                         cpu  ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                storage                           gpu     os  osv  weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    X    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    X    1.34
# ...

# %%
X=df["ram"].apply(lambda x:"Good" if x>=16 else "Average" if x>=8 else "Poor")
X
# Out:
# 0       Average
# 1       Average
# 2       Average
# 3          Good
# 4       Average
#          ...
# 1298       Poor
# 1299       Good
# 1300       Poor
# 1301       Poor
# 1302       Poor
# Name: ram, Length: 1303, dtype: object

# %%
# def changer(x,b):
#     if x>=16:
#         return b*"Good"
#     elif x>=8:
#         return b*"Average"
#     else:
#         return b*"Poor"
def changer(x):
    if x>=16:
        return "Good"
    elif x>=8:
        return "Average"
    else:
        return "Poor"

# %%
# df["ram"].apply(changer,args=(3,))
df["ram"].apply(changer)
# Out:
# 0       Average
# 1       Average
# 2       Average
# 3          Good
# 4       Average
#          ...
# 1298       Poor
# 1299       Good
# 1300       Poor
# 1301       Poor
# 1302       Poor
# Name: ram, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   manufacturer   model_name   category  screen_size  \
# 0        Apple  MacBook Pro  Ultrabook         13.3
# 1        Apple  Macbook Air  Ultrabook         13.3
# 2           HP       250 G6   Notebook         15.6
# 3        Apple  MacBook Pro  Ultrabook         15.4
# 4        Apple  MacBook Pro  Ultrabook         13.3
#
#                                screen                         cpu  ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                storage                           gpu     os  osv  weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    X    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    X    1.34
# ...

# %%
m=df.groupby("manufacturer")["screen_size"].mean()

# %%
m.sort_values()
# Out:
# manufacturer
# Google       12.300000
# Huawei       13.000000
# Apple        13.247619
# Mediacom     13.457143
# Microsoft    13.500000
# Samsung      13.822222
# Vero         13.825000
# Toshiba      14.354167
# Xiaomi       14.450000
# Chuwi        14.500000
# Razer        14.514286
# Lenovo       14.872727
# HP           14.943066
# Acer         15.063107
# LG           15.066667
# Dell         15.136027
# Asus         15.450000
# Fujitsu      15.600000
# MSI          16.442593
# Name: screen_size, dtype: float64

# %%
k=df.groupby("manufacturer")["screen_size"].agg(["min","max"])

# %%
k
# Out:
#                min   max
# manufacturer
# Acer          11.6  17.3
# Apple         11.6  15.4
# Asus          11.6  17.3
# Chuwi         12.3  15.6
# Dell          11.6  17.3
# Fujitsu       15.6  15.6
# Google        12.3  12.3
# HP            11.6  17.3
# Huawei        13.0  13.0
# LG            14.0  15.6
# Lenovo        10.1  17.3
# MSI           14.0  18.4
# Mediacom      11.6  14.0
# Microsoft     13.5  13.5
# Razer         12.5  17.3
# Samsung       11.6  15.6
# Toshiba       12.5  15.6
# Vero          13.3  14.0
# Xiaomi        13.3  15.6

# %%
cond=df["manufacturer"].isin(["Apple","Acer"])
k=df.loc[cond]
k
# Out:
#      manufacturer      model_name   category  screen_size  \
# 0           Apple     MacBook Pro  Ultrabook         13.3
# 1           Apple     Macbook Air  Ultrabook         13.3
# 3           Apple     MacBook Pro  Ultrabook         15.4
# 4           Apple     MacBook Pro  Ultrabook         13.3
# 5            Acer        Aspire 3   Notebook         15.6
# ...           ...             ...        ...          ...
# 1234        Apple     MacBook Air  Ultrabook         11.6
# 1242         Acer  Aspire ES1-572   Notebook         15.6
# 1263         Acer  Aspire ES1-531   Notebook         15.6
# 1277         Acer  Aspire ES1-531   Notebook         15.6
# 1291         Acer  Aspire ES1-531   Notebook         15.6
#
#                                   screen  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 3     IPS Panel Retina Display 2880x1800
# 4     IPS Panel Retina Display 2560x1600
# 5                               1366x768
# ...

# %%
k.value_counts()
# Out:
# manufacturer  model_name                                category   screen_size  screen                              cpu                                   ram  storage              gpu                      os       osv  weight  price_euros  cpu_name  storage_gb
# Acer          Aspire ES1-531                            Notebook   15.6         1366x768                            Intel Celeron Dual Core N3060 1.6GHz  4    500GB HDD            Intel HD Graphics 400    Linux    Y    2.40    289,00       Intel     500           3
#               Aspire 1                                  Notebook   14.0         Full HD 1920x1080                   Intel Celeron Quad Core N3450 1.1GHz  4    32GB Flash Storage   Intel HD Graphics 500    Windows  10   1.60    329,00       Intel     32            1
# ...

# %%
k.count()
# Out:
# manufacturer    124
# model_name      124
# category        124
# screen_size     124
# screen          124
# cpu             124
# ram             124
# storage         124
# gpu             124
# os              124
# osv             113
# weight          124
# price_euros     124
# cpu_name        124
# storage_gb      124
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', None, 'Eve', 'Frank', None],
    'Age': [25, np.nan, 30, 22, np.nan, 28, 35],
    'City': ['Delhi', 'Mumbai', None, 'Kolkata', 'Delhi', None, 'Bangalore'],
    'Salary': [50000, 60000, None, 45000, 52000, None, 61000],
    'Joining_Date': ['2021-01-10', None, '2020-05-20', '2021-03-15', None, '2020-08-09', '2021-02-12']
}

df3 = pd.DataFrame(data)

print(df3)
# Out:
#       Name   Age       City   Salary Joining_Date
# 0    Alice  25.0      Delhi  50000.0   2021-01-10
# 1      Bob   NaN     Mumbai  60000.0         None
# 2  Charlie  30.0       None      NaN   2020-05-20
# 3     None  22.0    Kolkata  45000.0   2021-03-15
# 4      Eve   NaN      Delhi  52000.0         None
# 5    Frank  28.0       None      NaN   2020-08-09
# 6     None  35.0  Bangalore  61000.0   2021-02-12

# %%
df3["Name"].fillna("😌")
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3          😌
# 4        Eve
# 5      Frank
# 6          😌
# Name: Name, dtype: object

# %%
import missingno as mno

# %%
mno.matrix(df)
# Out:
# <Axes: >

# %%
cond=df["manufacturer"]!="Apple"
cond
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Name: manufacturer, Length: 1303, dtype: bool

# %%
k=df.loc[cond]
k
# Out:
#      manufacturer                           model_name            category  \
# 2              HP                               250 G6            Notebook
# 5            Acer                             Aspire 3            Notebook
# 8            Asus                      ZenBook UX430UN           Ultrabook
# 9            Acer                              Swift 3           Ultrabook
# 10             HP                               250 G6            Notebook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       screen_size                                      screen  \
# ...

# %%
df[~df["manufacturer"].isin(["Apple","Acer"])]
# Out:
#      manufacturer                           model_name            category  \
# 2              HP                               250 G6            Notebook
# 8            Asus                      ZenBook UX430UN           Ultrabook
# 10             HP                               250 G6            Notebook
# 11             HP                               250 G6            Notebook
# 13           Dell                        Inspiron 3567            Notebook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       screen_size                                      screen  \
# ...

# %%
date="2025-11-10"

# %%
type(date)
# Out:
# str

# %%
date=pd.to_datetime(date)

# %%
type(date)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
date.month
# Out:
# 11

# %%
date.month_name()
# Out:
# 'November'
