# %%
import pandas as pd
import numpy as np

# %%
p1=pd.Series([100,200,300])                                      #creating a series
p1
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
p2=pd.Series([100,200,300],index=["a","b","c"])               #creating a series with custom index
p2
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
p1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
p1.index=["l","m","n"]                                          #modifying index labels

# %%
p1.index
# Out:
# Index(['l', 'm', 'n'], dtype='object')

# %%
p1[0]                                                           #accessing first element using index
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_20116\1178487653.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p1[0]
# np.int64(100)

# %%
p1["l"]
# Out:
# np.int64(100)

# %%
p1.sum()
# Out:
# np.int64(600)

# %%
p1.max()
# Out:
# np.int64(300)

# %%
p1.min()
# Out:
# np.int64(100)

# %%
type(p1)
# Out:
# pandas.core.series.Series

# %%
df1=pd.DataFrame({"Name":["Aaditya","Muskan","Chirag","Rohan"],"Marks":[87,97,91,78],"Age":[20,20,22,21],"Roll No.":[1,2,3,4]})    #creating a dataframe

# %%
df1
# Out:
#       Name  Marks  Age  Roll No.
# 0  Aaditya     87   20         1
# 1   Muskan     97   20         2
# 2   Chirag     91   22         3
# 3    Rohan     78   21         4

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.columns                                                       #accessing column labels
# Out:
# Index(['Name', 'Marks', 'Age', 'Roll No.'], dtype='object')

# %%
df1['Marks']                                                     #accessing a column
# Out:
# 0    87
# 1    97
# 2    91
# 3    78
# Name: Marks, dtype: int64

# %%
df1['Marks']=[90,100,95,85]

# %%
df1
# Out:
#       Name  Marks  Age  Roll No.
# 0  Aaditya     90   20         1
# 1   Muskan    100   20         2
# 2   Chirag     95   22         3
# 3    Rohan     85   21         4

# %%
df1.iloc[0:3,0:4]
# Out:
#       Name  Marks  Age  Roll No.
# 0  Aaditya     90   20         1
# 1   Muskan    100   20         2
# 2   Chirag     95   22         3
