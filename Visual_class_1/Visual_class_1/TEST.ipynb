# %%
import pandas as pd 
import numpy as np

# %%
who_time_series = pd.read_csv('WHO_time_series.csv')

# %%
who_time_series.head()
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
who_time_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  object
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %%
who_time_series['Country'].unique()
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia', 'Australia', 'Canada', 'Sri Lanka',
#        'Cambodia', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
#        'India', 'Philippines', 'Sweden', 'Russian Federation',
#        'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Egypt',
#        'Iran (Islamic Republic of)', 'Israel', 'Lebanon', 'Oman',
#        'Bahrain', 'Switzerland', 'Iraq', 'Afghanistan', 'Kuwait',
#        'Algeria', 'Austria', 'Romania', 'Norway', 'North Macedonia',
#        'Croatia', 'Georgia', 'Pakistan', 'Brazil', 'Denmark', 'Greece',
#        'Estonia', 'Nigeria', 'Lithuania', 'New Zealand', 'Mexico',
#        'Netherlands', 'San Marino', 'Ecuador', 'Monaco', 'Qatar',
#        'Azerbaijan', 'Belarus', 'Armenia', 'Czechia', 'Ireland',
#        'Iceland', 'Luxembourg', 'Morocco', 'Saint Barthélemy', 'Portugal',
# ...

# %%
import matplotlib.pyplot as plt
who_time_series['Date_reported']=pd.to_datetime(who_time_series['Date_reported'])

# %%
plt.plot(who_time_series['Date_reported'],who_time_series['Cumulative_cases'])
plt.show()

# %%
india=who_time_series[who_time_series['Country']=='India']

# %%
china=who_time_series[who_time_series['Country']=='China']

# %%
china
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0        2020-01-04   China          1                 1           0
# 1        2020-01-05   China          0                 1           0
# 2        2020-01-06   China          3                 4           0
# 3        2020-01-07   China          0                 4           0
# 4        2020-01-08   China          0                 4           0
# ...             ...     ...        ...               ...         ...
# 30853    2020-07-27   China        189             87028           0
# 31089    2020-07-28   China        217             87245           4
# 31273    2020-07-29   China        212             87457           1
# 31588    2020-07-30   China        223             87680           1
# 31675    2020-07-31   China        276             87956           1
#
#        Cumulative_deaths
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# ...

# %%
plt.plot(china['Date_reported'],china['Cumulative_cases'],ls="--",color="red")
plt.plot(india['Date_reported'],india['Cumulative_cases'],ls="--",color="blue")
plt.title("Covid Cases In China")
plt.xlabel("Data")
plt.ylabel("Cumulative Cases")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])

# %%
bike_sharing.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
plt.scatter(bike_sharing['atemp'],bike_sharing['cnt'])
plt.show()

# %%
plt.scatter(bike_sharing['windspeed'],bike_sharing['cnt'])
plt.show()

# %%
working_data=bike_sharing[bike_sharing['workingday']==1]

# %%
working_data
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# 5          6 2011-01-06       1   0     1        0        4           1
# 6          7 2011-01-07       1   0     1        0        5           1
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 723      724 2012-12-24       1   1    12        0        1           1
# 725      726 2012-12-26       1   1    12        0        3           1
# 726      727 2012-12-27       1   1    12        0        4           1
# 727      728 2012-12-28       1   1    12        0        5           1
# 730      731 2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
plt.scatter(bike_sharing['workingday'],bike_sharing['casual']) 
plt.scatter(bike_sharing['workingday'],bike_sharing['registered'])
plt.show()

# %%
bike_sharing.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
xy=bike_sharing.groupby(['mnth',"weekday"])["cnt"].agg(["mean","max","min"])

# %%
xy.iloc[0:50]
# Out:
#                      mean   max   min
# mnth weekday
# 1    0        1815.900000  3425   801
#      1        1926.800000  3624  1000
#      2        2567.777778  4509   683
#      3        2138.625000  4270   506
#      4        2513.250000  4097   431
#      5        2446.500000  4098  1167
#      6        1956.555556  4521   959
# 2    0        2247.500000  3389  1529
#      1        2604.375000  4322  1107
#      2        2824.000000  4375  1360
#      3        2813.333333  4773  1526
#      4        2878.500000  5062  1538
#      5        2933.125000  4154  1461
#      6        2266.500000  4318  1005
# 3    0        3301.000000  5892   605
#      1        3545.625000  6153  1872
#      2        3574.000000  6093  1851
#      3        3670.000000  6312  1536
#      4        3817.000000  6871   623
#      5        3925.777778  8362  1944
#      6        3938.777778  7836  2077
# 4    0        4416.888889  7132  1027
#      1        4515.777778  6370  3115
# ...

# %%
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])

# %%
bike_sharing.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
weekday_averages1=bike_sharing.groupby("weekday")[['registered','casual']].mean()

# %%
weekday_averages = bike_sharing.groupby('weekday').mean()[['casual', 'registered']].reset_index()

# %%
weekday_averages1
# Out:
#           registered       casual
# weekday
# 0        2890.533333  1338.295238
# 1        3663.990476   674.133333
# 2        3954.480769   556.182692
# 3        3997.394231   551.144231
# 4        4076.298077   590.961538
# 5        3938.000000   752.288462
# 6        3085.285714  1465.257143

# %%
weekday_averages
# Out:
#               casual   registered
# weekday
# 0        1338.295238  2890.533333
# 1         674.133333  3663.990476
# 2         556.182692  3954.480769
# 3         551.144231  3997.394231
# 4         590.961538  4076.298077
# 5         752.288462  3938.000000
# 6        1465.257143  3085.285714

# %%
test_series=pd.Series([12,13,23,45],index=['a','b','c','d'])

# %%
test_series
# Out:
# a    12
# b    13
# c    23
# d    45
# dtype: int64

# %%
test_1=bike_sharing[['dteday']]

# %%
type(test_1)
# Out:
# pandas.core.frame.DataFrame

# %%
test_1
# Out:
#         dteday
# 0   2011-01-01
# 1   2011-01-02
# 2   2011-01-03
# 3   2011-01-04
# 4   2011-01-05
# ..         ...
# 726 2012-12-27
# 727 2012-12-28
# 728 2012-12-29
# 729 2012-12-30
# 730 2012-12-31
#
# [731 rows x 1 columns]

# %%
plt.barh(weekday_averages['weekday'], weekday_averages['registered'],color=["red","blue","green","red","blue","green"])
# Out:
# <BarContainer object of 7 artists>

# %%
bike_sharing['cnt'].value_counts(bins=50).sort_values()
# Out:
# (195.84, 369.68]       0
# (13.307, 195.84]       1
# (8366.32, 8540.16]     1
# (8540.16, 8714.0]      2
# (369.68, 543.52]       3
# (8192.48, 8366.32]     3
# (717.36, 891.2]        4
# (8018.64, 8192.48]     5
# (543.52, 717.36]       5
# (7844.8, 8018.64]      6
# (2455.76, 2629.6]      7
# (7149.44, 7323.28]     8
# (1238.88, 1412.72]     9
# (1065.04, 1238.88]     9
# (891.2, 1065.04]      10
# (6280.24, 6454.08]    11
# (2803.44, 2977.28]    11
# (7670.96, 7844.8]     12
# (2977.28, 3151.12]    12
# (6627.92, 6801.76]    12
# (5932.56, 6106.4]     12
# (1934.24, 2108.08]    13
# (5758.72, 5932.56]    13
# (2629.6, 2803.44]     14
# (6454.08, 6627.92]    15
# (5584.88, 5758.72]    15
# (6975.6, 7149.44]     15
# (1586.56, 1760.4]     16
# (2108.08, 2281.92]    16
# (1760.4, 1934.24]     16
# (3151.12, 3324.96]    16
# (6106.4, 6280.24]     18
# (7497.12, 7670.96]    18
# (1412.72, 1586.56]    18
# (3846.48, 4020.32]    19
# (2281.92, 2455.76]    19
# (3324.96, 3498.8]     20
# ...

# %%
bike_sharing['cnt'].max()
# Out:
# 8714

# %%
plt.hist(bike_sharing['cnt'],bins=20)
plt.show()
